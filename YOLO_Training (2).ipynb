# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.

# %%
#The notebook's current working directory will be changed to darknet.
# %cd darknet
# Out:
# /content/darknet

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:253:21: warning: unused variable ‘n’ [-Wunused-variable]
#   253 |                 int n = _write(client, outputbuf, outlen);
#       |                     ^
# ./src/http_stream.cpp: In function ‘void set_track_id(detection*, int, float, float, float, int, int, int)’:
# ...

# %%
#Copy zip file path
# !cp /content/drive/MyDrive/DL_Works/obj.zip ../

# %%
# !pwd
# Out:
# /content/darknet

# %%
#Unzip the zip files (darknet->data->obj->ourfiles(numberplate images and textetc))
# !unzip ../obj.zip -d data/
# Out:
# Archive:  ../obj.zip
#    creating: data/obj/
#   inflating: data/obj/number1.jpeg
#   inflating: data/obj/number1.txt
#   inflating: data/obj/number2.jpeg
#   inflating: data/obj/number6.txt
#   inflating: data/obj/number3.jpeg
#   inflating: data/obj/number4.jpeg
#   inflating: data/obj/number5.jpeg
#   inflating: data/obj/number6.jpeg
#   inflating: data/obj/number7.jpeg
#   inflating: data/obj/number8.jpeg
#   inflating: data/obj/number9.jpeg
#   inflating: data/obj/number10.jpeg
#   inflating: data/obj/classes.txt
#   inflating: data/obj/number2.txt
#   inflating: data/obj/number3.txt
#   inflating: data/obj/number4.txt
#   inflating: data/obj/number5.txt
#   inflating: data/obj/number7.txt
#   inflating: data/obj/number8.txt
#   inflating: data/obj/number9.txt
#   inflating: data/obj/number10.txt

# %%
#Copy obj.names to data under daknet folder
# !cp /content/drive/MyDrive/DL_Works/obj.names ./data

# %%
# !cp /content/drive/MyDrive/DL_Works/obj.data ./data

# %%
# !cp /content/drive/MyDrive/DL_Works/yolov3_custom.cfg ./data

# %%
#Copy generate_train file to outside of data under darknet
# !cp /content/drive/MyDrive/DL_Works/generate_train.py ./

# %%
#run generate_train after editing the file extension by clicking on the file on left side
# !python generate_train.py
#then check on darknet->data->train.txt whether the all the files are present in the file(extension are changed as/content/darkness/data/obj/imagename.jpeg)

# %%
#download a pretrained model with 74 convolutional layers
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2024-06-27 05:04:14--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 162.0.215.52
# Connecting to pjreddie.com (pjreddie.com)|162.0.215.52|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  35.2MB/s    in 4.7s
#
# 2024-06-27 05:04:20 (32.7 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
#EDit the backup file path in the obj.data
# !/content/darknet/darknet detector train /content/darknet/data/obj.data /content/darknet/data/yolov3_custom.cfg /content/darknet/darknet53.conv.74 -dont_show
#-dont_show: Flag to restrict the graph from displayind
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 4731.223633, iou_loss = 0.000000, total_loss = 4731.223633
#  total_bbox = 456, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.159877), count: 2, class_loss = 341.738342, iou_loss = 3.341125, total_loss = 345.079468
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.327769), count: 2, class_loss = 866.180969, iou_loss = 0.885803, total_loss = 867.066772
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 4721.226562, iou_loss = 0.000000, total_loss = 4721.226562
#  total_bbox = 460, rewritten_bbox = 0.000000 %
# ...
